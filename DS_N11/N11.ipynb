# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1-  ![image.png](attachment:image.png)

# %%
import numpy as np
t= np.array([1, 1, 1, 2, 2, 3, 8, 3, 8, 8])
print(np.nonzero(t == 8))
print(np.nonzero(t == 8)[0])
print('cevap', np.nonzero(t == 8)[0][0])
# Out:
# (array([6, 8, 9], dtype=int64),)
# [6 8 9]
# cevap 6

# %% [markdown]
# 2-  ![image-2.png](attachment:image-2.png)

# %%
def sortTuples(tuples):
    return sorted(tuples, key=lambda x : x[1])
sortTuples([('b',1), ('c',2), ('x',3), ('x',4), ('z',0)])
# Out:
# [('z', 0), ('b', 1), ('c', 2), ('x', 3), ('x', 4)]

# %% [markdown]
# 3-  ![image.png](attachment:image.png)

# %% [markdown]
# yield is used like return in a function. But yield doesn't return the output, it returns generator. If you want to see in generator, you have to iterate.

# %% [markdown]
# 4-  ![image.png](attachment:image.png)

# %% [markdown]
# select name, population, area
# from Cities
# where area > 1000000 or
# population >25000000

# %% [markdown]
# 5-  ![image.png](attachment:image.png)

# %% [markdown]
# select nation, avg(age) as average_age
# from Players
# group by nation
# order by average_age desc

# %% [markdown]
# 6-  ![image.png](attachment:image.png)

# %%
def evaluate(var1, var2=4, var3=6):
    evaluation =var1*var2*var3
    print(evaluation)
evaluate(5,6)
# Out:
# 180

# %% [markdown]
# 7-  ![image.png](attachment:image.png)

# %% [markdown]
# classification is supervised learning, more complex and need train and tes data set. Clustering is unsupervised learning, less complex and no need tarin and test data set.

# %% [markdown]
# 8-  ![image.png](attachment:image.png)

# %% [markdown]
# ıt is one of the ACID transaction properties. in atomicity series of database operations either all occurs or nothing occurs.

# %% [markdown]
# 9-  ![image.png](attachment:image.png)

# %%
typos = [2,3,0,3,1,0,0,1]
import numpy as np
np.median(typos)
# Out:
# 1.0

# %% [markdown]
# 10-  ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# cevap B yani 2. şık

# %% [markdown]
# 11-  ![image.png](attachment:image.png)

# %%
def removeLast(your_list):
    return your_list[:-1]

# %% [markdown]
# 12-  ![image.png](attachment:image.png)

# %% [markdown]
# It is an error matrix and the table with two dimensions actual and predicted. That is often used to describe the performance of classification model
